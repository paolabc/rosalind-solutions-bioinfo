# %% [markdown]
# # Rosalind
# ####Solved Problem
# * Solve rosalind problems without libraries
# * https://rosalind.info/problems/dna/

# %%
sample='...'

#First option to solve
print(sample.replace('T','U'))

#second option to solve
dna_bases=[]
for i in sample:
    if i=='T':
       i='U'
    dna_bases.append(i)
result=''.join(dna_bases)
print(result)
